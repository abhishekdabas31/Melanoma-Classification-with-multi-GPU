# %%
# Imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Time

# %%
## GPU 1
df_1 = pd.read_csv("gpu1/plot_time.csv", header=None)
df_1.columns = ["Epochs", "Time"]
df_1["Epochs"] +=1


## GPU 2
df_2 = pd.read_csv("gpu2/plot_time.csv", header=None)
df_2.columns = ["Epochs", "Time"]
df_2["Epochs"] +=1



## GPU 4

df_4 = pd.read_csv("gpu4/plot_time.csv", header=None)
df_4.columns = ["Epochs", "Time"]
df_4["Epochs"] +=1

# %%
dict_time = {"GPU_1": 1374.71,
             "GPU_2": 1024.11,
             "GPU_3": 1262.101,
             "GPU_4": 800.09
    
}

# %%
plt.plot(*zip(*sorted(dict_time.items())), '--bo')
plt.title("Time/Epoch VS GPU Count")
plt.xlabel("GPU Count")
plt.ylabel("Time(sec)")
plt.show()

# %% [markdown]
# # Accuracy

# %%
dict_acc = {"GPU_1": 83.96,
             "GPU_2": 83.86,
            "GPU_3": 83.8,
             "GPU_4": 83.01
    
}

# %%
plt.plot(*zip(*sorted(dict_acc.items())), '--bo')
plt.title("Accuracy VS GPU Count")
plt.xlabel("GPU Count")
plt.ylabel("Accuracy(%))")
plt.show()

# %% [markdown]
# ## Loss

# %%
dict_loss = {"GPU_1": 0.078,
             "GPU_2": 0.077,
             "GPU_3":0.075,
             "GPU_4": 0.078
    
}

# %%
plt.plot(*zip(*sorted(dict_loss.items())), '--bo')
plt.title("Loss VS GPU Count")
plt.xlabel("GPU Count")
plt.ylabel("Loss")
plt.show()
